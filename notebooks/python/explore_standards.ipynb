# %%
import psycopg2

# information used to create a database connection
sqluser = 'postgres'
dbname = 'mimic4'
hostname = 'localhost'
port_number = 5434
schema_name = 'omop_cdm'

# Connect to postgres with a copy of the MIMIC-III database
con = psycopg2.connect(dbname=dbname, user=sqluser, host=hostname, port=port_number, password='mysecretpassword')

# the below statement is prepended to queries to ensure they select from the right schema
query_schema = 'set search_path to ' + schema_name + ';'

# %%
import pandas as pd

countsQuery = """
    select
    count(*) as total_count,
    count(distinct domain_id) as total_domains,
    count(distinct vocabulary_id) as total_vocabularies,
    count(distinct concept_class_id) as total_concept_classes,
    count(distinct concept_name) as total_concepts
    from
    voc_dataset.concept
    ;
"""
countsDf = pd.read_sql_query(countsQuery, con)
countsDf
# Out:
#    total_count  total_domains  total_vocabularies  total_concept_classes  \
# 0      5591082             33                  82                    184
#
#    total_concepts
# 0         4104016

# %%
import pandas as pd

countsQuery = """
    select
    domain_id as "Domain",
    count(*) as "Domain Count",
    sum(case when standard_concept = 'S' then 1 else 0 end) as "Standard Count",
    sum(case when standard_concept = 'S' then 0 else 1 end) as "Customised Count"
    from
    voc_dataset.concept
    where invalid_reason is null
    group by domain_id
    order by "Domain Count" desc
    ;
"""
countsDf = pd.read_sql_query(countsQuery, con)
countsDf
# Out:
# /home/yram0006/phd/chapter_1/workspace/EHR-standards/.venv/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#                  Domain  Domain Count  Standard Count  Customised Count
# 0                  Drug       3449769         1920734           1529035
# 1                Device        219481          218153              1328
# 2             Condition        218354          112889            105465
# 3           Observation        209491          137986             71505
# 4             Geography        203352          203352                 0
# 5           Measurement        138256           91891             46365
# 6             Procedure         56223           53242              2981
# 7    Spec Anatomic Site         34702           34695                 7
# 8            Meas Value         19110           19080                30
# 9              Metadata          3357             992              2365
# 10                 Unit          2290             921              1369
# 11         Type Concept          2079              88              1991
# 12             Specimen          1894            1809                85
# 13             Provider          1358             681               677
# 14                Visit          1090             259               831
# 15         Revenue Code           545             545                 0
# 16                 Race           485              53               432
# 17                Route           279             183                96
# 18         Relationship           194             194                 0
# 19             Currency           180             180                 0
# 20                Payer           162             158                 4
# 21                 Cost            51              51                 0
# 22     Condition Status            22              22                 0
# 23              Episode            14              14                 0
# 24     Plan Stop Reason            13              13                 0
# 25               Gender            12               2                10
# 26                 Plan            11              11                 0
# 27              Sponsor             6               6                 0
# 28  Meas Value Operator             5               5                 0
# 29            Ethnicity             3               2                 1
# 30  Spec Disease Status             3               3                 0

# %%
import pandas as pd

ethnicityQuery = """
    select * from voc_dataset.concept where domain_id = 'Ethnicity';
"""
ethnicityDf = pd.read_sql_query(ethnicityQuery, con)
ethnicityDf
# Out:
# /home/yram0006/phd/chapter_1/workspace/EHR-standards/.venv/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    concept_id            concept_name  domain_id          vocabulary_id  \
# 0  2000001408         HISPANIC/LATINO  Ethnicity  mimiciv_per_ethnicity
# 1    38003563      Hispanic or Latino  Ethnicity              Ethnicity
# 2    38003564  Not Hispanic or Latino  Ethnicity              Ethnicity
#
#   concept_class_id standard_concept     concept_code valid_start_date  \
# 0        Ethnicity             None  HISPANIC/LATINO       1970-01-01
# 1        Ethnicity                S         Hispanic       1970-01-01
# 2        Ethnicity                S     Not Hispanic       1970-01-01
#
#   valid_end_date invalid_reason       load_table_id   load_row_id
# 0     2099-12-31           None  tmp_custom_mapping           NaN
# 1     2099-12-31           None             concept  1.160080e+09
# 2     2099-12-31           None             concept  5.698891e+08

# %%
import pandas as pd

ethnicityQuery = """
    select
    distinct PER.ethnicity_concept_id
    from
    omop_cdm.person PER
    ;
"""
ethnicityDf = pd.read_sql_query(ethnicityQuery, con)
ethnicityDf
# Out:
# /home/yram0006/phd/chapter_1/workspace/EHR-standards/.venv/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    ethnicity_concept_id
# 0                     0
# 1              38003563

# %%
import pandas as pd

raceQuery = """
    select * from voc_dataset.concept where domain_id = 'Race';
"""
raceDf = pd.read_sql_query(raceQuery, con)
raceDf
# Out:
# /home/yram0006/phd/chapter_1/workspace/EHR-standards/.venv/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#      concept_id                      concept_name domain_id  \
# 0      38003607                          Tobagoan      Race
# 1      38003608                       Trinidadian      Race
# 2          8657  American Indian or Alaska Native      Race
# 3      38003572                   American Indian      Race
# 4      38003573                     Alaska Native      Race
# ..          ...                               ...       ...
# 766  2000001402                             OTHER      Race
# 767  2000001403                             ASIAN      Race
# 768  2000001407     AMERICAN INDIAN/ALASKA NATIVE      Race
# 769  2000001404                             WHITE      Race
# 770  2000001405                  UNABLE TO OBTAIN      Race
#
#              vocabulary_id concept_class_id standard_concept  \
# 0                     Race             Race                S
# 1                     Race             Race                S
# 2                     Race             Race                S
# 3                     Race             Race                S
# 4                     Race             Race                S
# ..                     ...              ...              ...
# 766  mimiciv_per_ethnicity             Race                S
# 767  mimiciv_per_ethnicity             Race             None
# 768  mimiciv_per_ethnicity             Race             None
# 769  mimiciv_per_ethnicity             Race             None
# 770  mimiciv_per_ethnicity             Race                S
#
#                       concept_code valid_start_date valid_end_date  \
# 0                             3.10       1970-01-01     2099-12-31
# 1                             3.11       1970-01-01     2099-12-31
# 2                                1       1970-01-01     2099-12-31
# 3                             1.01       1970-01-01     2099-12-31
# 4                             1.02       1970-01-01     2099-12-31
# ..                             ...              ...            ...
# 766                          OTHER       1970-01-01     2099-12-31
# 767                          ASIAN       1970-01-01     2099-12-31
# 768  AMERICAN INDIAN/ALASKA NATIVE       1970-01-01     2099-12-31
# 769                          WHITE       1970-01-01     2099-12-31
# 770               UNABLE TO OBTAIN       1970-01-01     2099-12-31
#
#     invalid_reason       load_table_id   load_row_id
# 0             None             concept  1.749408e+09
# 1             None             concept -2.793061e+07
# 2             None             concept  1.783987e+09
# 3             None             concept  1.016136e+09
# 4             None             concept  5.091420e+08
# ..             ...                 ...           ...
# 766           None  tmp_custom_mapping           NaN
# 767           None  tmp_custom_mapping           NaN
# 768           None  tmp_custom_mapping           NaN
# 769           None  tmp_custom_mapping           NaN
# 770           None  tmp_custom_mapping           NaN
#
# [771 rows x 12 columns]

# %%
import pandas as pd

raceQuery = """
    select
    PER.race_concept_id as race_concept_id,
    CON.concept_code as concept_code,
    CON.concept_name as concept_name,
    CON.vocabulary_id as vocabulary_id,
    count(*) as total_count
    from
    omop_cdm.person PER
    left join voc_dataset.concept CON
    on PER.race_concept_id = CON.concept_id
    group by PER.race_concept_id, CON.vocabulary_id, CON.concept_code, CON.concept_name
    ;
"""
raceDf = pd.read_sql_query(raceQuery, con)
raceDf
# Out:
# /home/yram0006/phd/chapter_1/workspace/EHR-standards/.venv/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    race_concept_id         concept_code                      concept_name  \
# 0                0  No matching concept               No matching concept
# 1             8515                    2                             Asian
# 2             8516                    3         Black or African American
# 3             8527                    5                             White
# 4             8657                    1  American Indian or Alaska Native
# 5       2000001401              UNKNOWN                           UNKNOWN
# 6       2000001402                OTHER                             OTHER
# 7       2000001405     UNABLE TO OBTAIN                  UNABLE TO OBTAIN
#
#            vocabulary_id  total_count
# 0                   None        94444
# 1                   Race        16446
# 2                   Race        30946
# 3                   Race       158683
# 4                   Race          940
# 5  mimiciv_per_ethnicity        17069
# 6  mimiciv_per_ethnicity        16040
# 7  mimiciv_per_ethnicity         3374
