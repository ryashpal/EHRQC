# %%
# Install medcat
! pip install medcat==1.5.0
try:
    from medcat.cat import CAT
except:
    print("WARNING: Runtime will restart automatically and please run other cells thereafter.")
    exit()
# Out:
# Collecting medcat==1.5.0
#   Downloading medcat-1.5.0-py3-none-any.whl (141 kB)
#      |████████████████████████████████| 141 kB 28.7 MB/s eta 0:00:01
# Collecting pandas<=1.4.2,>=1.1.5
#   Downloading pandas-1.4.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#      |████████████████████████████████| 11.7 MB 94.7 MB/s eta 0:00:01
# Requirement already satisfied: tqdm>=4.27 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from medcat==1.5.0) (4.64.1)
# Requirement already satisfied: jsonpickle~=2.0.0 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from medcat==1.5.0) (2.0.0)
# Requirement already satisfied: click<=8.0.4 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from medcat==1.5.0) (7.1.2)
# Requirement already satisfied: gensim~=4.1.2 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from medcat==1.5.0) (4.1.2)
# Requirement already satisfied: numpy>=1.21.4 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from medcat==1.5.0) (1.24.1)
# Requirement already satisfied: scikit-learn<1.2.0 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from medcat==1.5.0) (1.1.3)
# Requirement already satisfied: datasets~=2.2.2 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from medcat==1.5.0) (2.2.2)
# Collecting spacy<3.1.4,>=3.1.0
#   Using cached spacy-3.1.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
# Requirement already satisfied: eland<9,>=8.3.0 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from medcat==1.5.0) (8.3.0)
# Requirement already satisfied: aiofiles~=0.8.0 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from medcat==1.5.0) (0.8.0)
# Requirement already satisfied: xxhash==3.0.0 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from medcat==1.5.0) (3.0.0)
# Requirement already satisfied: multiprocess==0.70.12 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from medcat==1.5.0) (0.70.12)
# Requirement already satisfied: torch>=1.0 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from medcat==1.5.0) (1.13.1)
# Requirement already satisfied: psutil<6.0.0,>=5.8.0 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from medcat==1.5.0) (5.9.4)
# Requirement already satisfied: joblib~=1.2 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from medcat==1.5.0) (1.2.0)
# Requirement already satisfied: smart-open==5.2.1 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from medcat==1.5.0) (5.2.1)
# Requirement already satisfied: ipywidgets~=7.6.5 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from medcat==1.5.0) (7.6.6)
# Collecting scipy<=1.8.1,>=1.5.4
#   Downloading scipy-1.8.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.2 MB)
#      |████████████████████████████████| 42.2 MB 143 kB/s  eta 0:00:01
# Requirement already satisfied: blis<=0.7.5 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from medcat==1.5.0) (0.7.5)
# Requirement already satisfied: elasticsearch<9,>=8.3 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from medcat==1.5.0) (8.6.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from medcat==1.5.0) (1.8.2)
# Requirement already satisfied: dill<0.3.5,~=0.3.4 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from medcat==1.5.0) (0.3.4)
# Requirement already satisfied: py2neo==2021.2.3 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from medcat==1.5.0) (2021.2.3)
# Requirement already satisfied: transformers~=4.19.2 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from medcat==1.5.0) (4.19.4)
# Requirement already satisfied: aiohttp==3.8.3 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from medcat==1.5.0) (3.8.3)
# Requirement already satisfied: pytz>=2020.1 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from pandas<=1.4.2,>=1.1.5->medcat==1.5.0) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from pandas<=1.4.2,>=1.1.5->medcat==1.5.0) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from scikit-learn<1.2.0->medcat==1.5.0) (3.1.0)
# Requirement already satisfied: requests>=2.19.0 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from datasets~=2.2.2->medcat==1.5.0) (2.28.1)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from datasets~=2.2.2->medcat==1.5.0) (0.11.1)
# Requirement already satisfied: pyarrow>=6.0.0 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from datasets~=2.2.2->medcat==1.5.0) (10.0.1)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from datasets~=2.2.2->medcat==1.5.0) (2022.11.0)
# Requirement already satisfied: packaging in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from datasets~=2.2.2->medcat==1.5.0) (23.0)
# Requirement already satisfied: responses<0.19 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from datasets~=2.2.2->medcat==1.5.0) (0.18.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from spacy<3.1.4,>=3.1.0->medcat==1.5.0) (3.0.8)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from spacy<3.1.4,>=3.1.0->medcat==1.5.0) (0.10.1)
# Requirement already satisfied: setuptools in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from spacy<3.1.4,>=3.1.0->medcat==1.5.0) (44.0.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.9 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from spacy<3.1.4,>=3.1.0->medcat==1.5.0) (8.0.17)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from spacy<3.1.4,>=3.1.0->medcat==1.5.0) (3.0.11)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from spacy<3.1.4,>=3.1.0->medcat==1.5.0) (2.0.7)
# Requirement already satisfied: jinja2 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from spacy<3.1.4,>=3.1.0->medcat==1.5.0) (3.1.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from spacy<3.1.4,>=3.1.0->medcat==1.5.0) (2.0.8)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from spacy<3.1.4,>=3.1.0->medcat==1.5.0) (0.3.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from spacy<3.1.4,>=3.1.0->medcat==1.5.0) (2.4.5)
# Requirement already satisfied: pathy>=0.3.5 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from spacy<3.1.4,>=3.1.0->medcat==1.5.0) (0.10.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from spacy<3.1.4,>=3.1.0->medcat==1.5.0) (1.0.9)
# Requirement already satisfied: matplotlib<4 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from eland<9,>=8.3.0->medcat==1.5.0) (3.6.2)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66; platform_system == "Linux" in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from torch>=1.0->medcat==1.5.0) (11.10.3.66)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96; platform_system == "Linux" in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from torch>=1.0->medcat==1.5.0) (8.5.0.96)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99; platform_system == "Linux" in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from torch>=1.0->medcat==1.5.0) (11.7.99)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99; platform_system == "Linux" in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from torch>=1.0->medcat==1.5.0) (11.7.99)
# Requirement already satisfied: typing-extensions in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from torch>=1.0->medcat==1.5.0) (4.4.0)
# Requirement already satisfied: nbformat>=4.2.0 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from ipywidgets~=7.6.5->medcat==1.5.0) (5.7.3)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0; python_version >= "3.6" in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from ipywidgets~=7.6.5->medcat==1.5.0) (1.1.1)
# Requirement already satisfied: traitlets>=4.3.1 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from ipywidgets~=7.6.5->medcat==1.5.0) (5.8.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from ipywidgets~=7.6.5->medcat==1.5.0) (6.20.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from ipywidgets~=7.6.5->medcat==1.5.0) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from ipywidgets~=7.6.5->medcat==1.5.0) (3.5.2)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from ipywidgets~=7.6.5->medcat==1.5.0) (8.8.0)
# Requirement already satisfied: elastic-transport<9,>=8 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from elasticsearch<9,>=8.3->medcat==1.5.0) (8.4.0)
# Requirement already satisfied: pansi>=2020.7.3 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from py2neo==2021.2.3->medcat==1.5.0) (2020.7.3)
# Requirement already satisfied: monotonic in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from py2neo==2021.2.3->medcat==1.5.0) (1.6)
# Requirement already satisfied: interchange~=2021.0.4 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from py2neo==2021.2.3->medcat==1.5.0) (2021.0.4)
# Requirement already satisfied: urllib3 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from py2neo==2021.2.3->medcat==1.5.0) (1.26.13)
# Requirement already satisfied: six>=1.15.0 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from py2neo==2021.2.3->medcat==1.5.0) (1.16.0)
# Requirement already satisfied: pygments>=2.0.0 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from py2neo==2021.2.3->medcat==1.5.0) (2.14.0)
# Requirement already satisfied: certifi in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from py2neo==2021.2.3->medcat==1.5.0) (2022.12.7)
# Requirement already satisfied: pyyaml>=5.1 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from transformers~=4.19.2->medcat==1.5.0) (6.0)
# Requirement already satisfied: filelock in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from transformers~=4.19.2->medcat==1.5.0) (3.9.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from transformers~=4.19.2->medcat==1.5.0) (0.12.1)
# Requirement already satisfied: regex!=2019.12.17 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from transformers~=4.19.2->medcat==1.5.0) (2022.10.31)
# Requirement already satisfied: frozenlist>=1.1.1 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from aiohttp==3.8.3->medcat==1.5.0) (1.3.3)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from aiohttp==3.8.3->medcat==1.5.0) (2.1.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from aiohttp==3.8.3->medcat==1.5.0) (6.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from aiohttp==3.8.3->medcat==1.5.0) (22.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from aiohttp==3.8.3->medcat==1.5.0) (1.8.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from aiohttp==3.8.3->medcat==1.5.0) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from aiohttp==3.8.3->medcat==1.5.0) (4.0.2)
# Requirement already satisfied: idna<4,>=2.5 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from requests>=2.19.0->datasets~=2.2.2->medcat==1.5.0) (3.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from jinja2->spacy<3.1.4,>=3.1.0->medcat==1.5.0) (2.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from matplotlib<4->eland<9,>=8.3.0->medcat==1.5.0) (1.0.6)
# Requirement already satisfied: pyparsing>=2.2.1 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from matplotlib<4->eland<9,>=8.3.0->medcat==1.5.0) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from matplotlib<4->eland<9,>=8.3.0->medcat==1.5.0) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from matplotlib<4->eland<9,>=8.3.0->medcat==1.5.0) (9.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from matplotlib<4->eland<9,>=8.3.0->medcat==1.5.0) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from matplotlib<4->eland<9,>=8.3.0->medcat==1.5.0) (4.38.0)
# Requirement already satisfied: wheel in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66; platform_system == "Linux"->torch>=1.0->medcat==1.5.0) (0.38.4)
# Requirement already satisfied: jsonschema>=2.6 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets~=7.6.5->medcat==1.5.0) (4.17.3)
# Requirement already satisfied: jupyter-core in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets~=7.6.5->medcat==1.5.0) (5.1.3)
# Requirement already satisfied: fastjsonschema in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets~=7.6.5->medcat==1.5.0) (2.16.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets~=7.6.5->medcat==1.5.0) (7.4.9)
# Requirement already satisfied: pyzmq>=17 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets~=7.6.5->medcat==1.5.0) (25.0.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets~=7.6.5->medcat==1.5.0) (0.1.6)
# Requirement already satisfied: comm>=0.1.1 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets~=7.6.5->medcat==1.5.0) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets~=7.6.5->medcat==1.5.0) (1.6.5)
# Requirement already satisfied: nest-asyncio in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets~=7.6.5->medcat==1.5.0) (1.5.6)
# Requirement already satisfied: tornado>=6.1 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets~=7.6.5->medcat==1.5.0) (6.2)
# Requirement already satisfied: notebook>=4.4.1 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets~=7.6.5->medcat==1.5.0) (6.5.2)
# Requirement already satisfied: jedi>=0.16 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets~=7.6.5->medcat==1.5.0) (0.18.2)
# Requirement already satisfied: decorator in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets~=7.6.5->medcat==1.5.0) (5.1.1)
# Requirement already satisfied: backcall in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets~=7.6.5->medcat==1.5.0) (0.2.0)
# Requirement already satisfied: stack-data in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets~=7.6.5->medcat==1.5.0) (0.6.2)
# Requirement already satisfied: pickleshare in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets~=7.6.5->medcat==1.5.0) (0.7.5)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets~=7.6.5->medcat==1.5.0) (4.8.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.11 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets~=7.6.5->medcat==1.5.0) (3.0.36)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets~=7.6.5->medcat==1.5.0) (0.19.3)
# Requirement already satisfied: platformdirs>=2.5 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets~=7.6.5->medcat==1.5.0) (2.6.2)
# Requirement already satisfied: entrypoints in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets~=7.6.5->medcat==1.5.0) (0.4)
# Requirement already satisfied: argon2-cffi in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets~=7.6.5->medcat==1.5.0) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets~=7.6.5->medcat==1.5.0) (0.17.1)
# Requirement already satisfied: prometheus-client in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets~=7.6.5->medcat==1.5.0) (0.15.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets~=7.6.5->medcat==1.5.0) (1.8.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets~=7.6.5->medcat==1.5.0) (0.4.8)
# Requirement already satisfied: nbconvert>=5 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets~=7.6.5->medcat==1.5.0) (7.2.7)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=4.0.0; python_version >= "3.3"->ipywidgets~=7.6.5->medcat==1.5.0) (0.8.3)
# Requirement already satisfied: pure-eval in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from stack-data->ipython>=4.0.0; python_version >= "3.3"->ipywidgets~=7.6.5->medcat==1.5.0) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from stack-data->ipython>=4.0.0; python_version >= "3.3"->ipywidgets~=7.6.5->medcat==1.5.0) (2.2.1)
# Requirement already satisfied: executing>=1.2.0 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from stack-data->ipython>=4.0.0; python_version >= "3.3"->ipywidgets~=7.6.5->medcat==1.5.0) (1.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from pexpect>4.3; sys_platform != "win32"->ipython>=4.0.0; python_version >= "3.3"->ipywidgets~=7.6.5->medcat==1.5.0) (0.7.0)
# Requirement already satisfied: wcwidth in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.11->ipython>=4.0.0; python_version >= "3.3"->ipywidgets~=7.6.5->medcat==1.5.0) (0.2.5)
# Requirement already satisfied: argon2-cffi-bindings in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets~=7.6.5->medcat==1.5.0) (21.2.0)
# Requirement already satisfied: notebook-shim>=0.1.0 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets~=7.6.5->medcat==1.5.0) (0.2.2)
# Requirement already satisfied: jupyter-server>=1.8 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets~=7.6.5->medcat==1.5.0) (2.0.6)
# Requirement already satisfied: jupyterlab-pygments in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets~=7.6.5->medcat==1.5.0) (0.2.2)
# Requirement already satisfied: importlib-metadata>=3.6; python_version < "3.10" in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets~=7.6.5->medcat==1.5.0) (6.0.0)
# Requirement already satisfied: mistune<3,>=2.0.3 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets~=7.6.5->medcat==1.5.0) (2.0.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets~=7.6.5->medcat==1.5.0) (1.5.0)
# Requirement already satisfied: nbclient>=0.5.0 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets~=7.6.5->medcat==1.5.0) (0.7.2)
# Requirement already satisfied: bleach in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets~=7.6.5->medcat==1.5.0) (5.0.1)
# Requirement already satisfied: defusedxml in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets~=7.6.5->medcat==1.5.0) (0.7.1)
# Requirement already satisfied: tinycss2 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets~=7.6.5->medcat==1.5.0) (1.2.1)
# Requirement already satisfied: beautifulsoup4 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets~=7.6.5->medcat==1.5.0) (4.11.1)
# Requirement already satisfied: cffi>=1.0.1 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets~=7.6.5->medcat==1.5.0) (1.15.1)
# Requirement already satisfied: jupyter-events>=0.4.0 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets~=7.6.5->medcat==1.5.0) (0.6.3)
# Requirement already satisfied: websocket-client in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets~=7.6.5->medcat==1.5.0) (1.4.2)
# Requirement already satisfied: jupyter-server-terminals in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets~=7.6.5->medcat==1.5.0) (0.4.4)
# Requirement already satisfied: anyio<4,>=3.1.0 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets~=7.6.5->medcat==1.5.0) (3.6.2)
# Requirement already satisfied: zipp>=0.5 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from importlib-metadata>=3.6; python_version < "3.10"->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets~=7.6.5->medcat==1.5.0) (3.11.0)
# Requirement already satisfied: webencodings in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets~=7.6.5->medcat==1.5.0) (0.5.1)
# Requirement already satisfied: soupsieve>1.2 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets~=7.6.5->medcat==1.5.0) (2.3.2.post1)
# Requirement already satisfied: pycparser in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets~=7.6.5->medcat==1.5.0) (2.21)
# Requirement already satisfied: python-json-logger>=2.0.4 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets~=7.6.5->medcat==1.5.0) (2.0.4)
# Requirement already satisfied: rfc3339-validator in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets~=7.6.5->medcat==1.5.0) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets~=7.6.5->medcat==1.5.0) (0.1.1)
# Requirement already satisfied: sniffio>=1.1 in /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets~=7.6.5->medcat==1.5.0) (1.3.0)
# ERROR: en-core-web-md 3.0.0 has requirement spacy<3.1.0,>=3.0.0, but you'll have spacy 3.1.3 which is incompatible.
# ERROR: en-core-sci-md 0.4.0 has requirement spacy<3.1.0,>=3.0.1, but you'll have spacy 3.1.3 which is incompatible.
# ERROR: en-core-sci-lg 0.4.0 has requirement spacy<3.1.0,>=3.0.1, but you'll have spacy 3.1.3 which is incompatible.
# Installing collected packages: pandas, spacy, scipy, medcat
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.2
#     Uninstalling pandas-1.5.2:
#       Successfully uninstalled pandas-1.5.2
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.0.8
#     Uninstalling spacy-3.0.8:
#       Successfully uninstalled spacy-3.0.8
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.10.0
#     Uninstalling scipy-1.10.0:
#       Successfully uninstalled scipy-1.10.0
#   Attempting uninstall: medcat
#     Found existing installation: medcat 1.6.0
#     Uninstalling medcat-1.6.0:
#       Successfully uninstalled medcat-1.6.0
# Successfully installed medcat-1.5.0 pandas-1.4.2 scipy-1.8.1 spacy-3.1.3
# /home/yram0006/phd/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages/medcat/cat.py:18: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
from medcat.cat import CAT

baseDir = '/superbugai-data/yash/temp/'
model_pack_path = baseDir + "mc_modelpack_snomed_int_16_mar_2022/mc_modelpack_snomed_int_16_mar_2022_25be3857ba34bdd5.zip"

# Load model pack and Create CAT - the main class from medcat used for concept annotation
# Create the full pipeline with models for meta-annotations
cat = CAT.load_model_pack(model_pack_path)

# %%
entities = cat.get_entities('diabetes')['entities']

# %%
entities
# Out:
# {0: {'pretty_name': 'Diabetes mellitus',
#   'cui': '73211009',
#   'type_ids': ['9090192'],
#   'types': ['disorder'],
#   'source_value': 'diabetes',
#   'detected_name': 'diabetes',
#   'acc': 0.7395656940759914,
#   'context_similarity': 0.7395656940759914,
#   'start': 0,
#   'end': 8,
#   'icd10': ['E14.9'],
#   'ontologies': ['SNOMED-CT'],
#   'snomed': [],
#   'id': 0,
#   'meta_anns': {'Status': {'value': 'Affirmed',
#     'confidence': 0.9972876906394958,
#     'name': 'Status'}}}}
