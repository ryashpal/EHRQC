# %%
import pandas as pd

medcatIllnessDf = pd.read_csv('data/mapped_20002_non_cancer_illness_last_child_medcat.csv', dtype=str)
medcatIllnessDf
# Out:
#     source_concept_id              source_concept_name  \
# 0                1220                         diabetes
# 1                1638                    fracture hand
# 2                1552                  uterine problem
# 3                1120                       asbestosis
# 4                1328                      haemophilia
# ..                ...                              ...
# 441              1402                    endometriosis
# 442              1250  bell's palsy/facial nerve palsy
# 443              1403               female infertility
# 444              1404                 male infertility
# 445              1405       other renal/kidney problem
#
#                                matching_concept_entity matching_concept_score
# 0                                                   {}                    0.0
# 1                                                   {}                    0.0
# ...

# %%
import ast

medcatIllnessDf.matching_concept_entity.apply(ast.literal_eval).apply(len).value_counts()
# Out:
# 0    433
# 1     13
# Name: matching_concept_entity, dtype: int64

# %%
import pandas as pd

medcatOperationDf = pd.read_csv('data/mapped_20004_operation_last_child_medcat.csv', dtype=str)
medcatOperationDf
# Out:
#     source_concept_id    source_concept_name matching_concept_entity  \
# 0                1603           scan / x-ray                      {}
# 1                1599           exercise ecg                      {}
# 2                1450          liver surgery                      {}
# 3                1537     lymph node surgery                      {}
# 4                1615     bone marrow biopsy                      {}
# ..                ...                    ...                     ...
# 249              1457  pancreatic transplant                      {}
# 250              1442      amputation of toe                      {}
# 251              1440      amputation of leg                      {}
# 252              1360   endometrial ablation                      {}
# 253              1098       heart transplant                      {}
#
#     matching_concept_score
# 0                      0.0
# 1                      0.0
# 2                      0.0
# ...

# %%
import ast

medcatOperationDf.matching_concept_entity.apply(ast.literal_eval).apply(len).value_counts()
# Out:
# 0    253
# 1      1
# Name: matching_concept_entity, dtype: int64

# %%
import pandas as pd

fuzzyOperationDf = pd.read_csv('data/mapped_20004_operation_last_child.csv', dtype=str)
fuzzyOperationDf
# Out:
#     source_concept_id    source_concept_name  \
# 0                1603           scan / x-ray
# 1                1599           exercise ecg
# 2                1450          liver surgery
# 3                1537     lymph node surgery
# 4                1615     bone marrow biopsy
# ..                ...                    ...
# 249              1457  pancreatic transplant
# 250              1442      amputation of toe
# 251              1440      amputation of leg
# 252              1360   endometrial ablation
# 253              1098       heart transplant
#
#                    matching_concept_name matching_concept_id  \
# 0                   Standard chest X-ray             4056836
# 1                     Exercise challenge             4029347
# 2                           Acne surgery             4144834
# 3                           Acne surgery             4144834
# 4                  Biopsy of carpal bone            40490979
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns

fig, ax = plt.subplots()

sns.distplot(fuzzyOperationDf.matching_concept_score, hist=False, color='red', ax=ax)
# Out:
# /home/yram0006/phd/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/yram0006/phd/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='matching_concept_score', ylabel='Density'>

# %%
import pandas as pd

fuzzyIllnessDf = pd.read_csv('data/mapped_20002_non_cancer_illness_last_child.csv', dtype=str)
fuzzyIllnessDf
# Out:
#     source_concept_id              source_concept_name  \
# 0                1220                         diabetes
# 1                1638                    fracture hand
# 2                1552                  uterine problem
# 3                1120                       asbestosis
# 4                1328                      haemophilia
# ..                ...                              ...
# 441              1402                    endometriosis
# 442              1250  bell's palsy/facial nerve palsy
# 443              1403               female infertility
# 444              1404                 male infertility
# 445              1405       other renal/kidney problem
#
#            matching_concept_name matching_concept_id matching_concept_score
# 0                    Prediabetes            37018196                     84
# 1                  Fracture pain            37116825                     85
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns

fig, ax = plt.subplots()

sns.distplot(fuzzyIllnessDf.matching_concept_score, hist=False, color='red', ax=ax)
# Out:
# /home/yram0006/phd/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='matching_concept_score', ylabel='Density'>
